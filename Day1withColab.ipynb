# %%
import random
import sys
import os

# %%
print("Hello World")
# Out:
# Hello World

# %%
name="Chaitra"
print(name)
# Out:
# Chaitra

# %%
# comment
''' Numbers string
tuple dictionary list
''' 
#String
quote="\"Always remember you are unique"
print(quote)
# / is escape character
multi_line_quote = ''' just like 
everybody else'''
new_string = quote + multi_line_quote
print(new_string)
# Out:
# "Always remember you are unique
# "Always remember you are unique just like
# everybody else

# %%
print("%s %s %s" % ('stay strong and',quote,multi_line_quote))
# Out:
# stay strong and "Always remember you are unique  just like
# everybody else

# %%
print("i dont like new ", end="")
print("lines")
# Out:
# i dont like new lines

# %%
print("My name is %s" % ('quote'))
# Out:
# My name is quote

# %%
#List
grocery_list=['tomatoes','potatoes','Juice']
print(grocery_list[0])
# Out:
# tomatoes

# %%
grocery_list[0]= "honey"
print('first Item',grocery_list[0])
grocery_list
# Out:
# first Item honey
# ['honey', 'potatoes', 'Juice']

# %%
#print sub-set of list
grocery_list[1:3]
# Out:
# ['potatoes', 'Juice']

# %%
#list inside a list
other_items=['do 255 assignment', '256 assignment']
to_do_list = [grocery_list,other_items]
to_do_list
# Out:
# [['honey', 'potatoes', 'Juice'], ['do 255 assignment', '256 assignment']]

# %%
print(to_do_list[1][1])
# Out:
# 256 assignment

# %%
to_do_list.append('272 enterprise software')
print(to_do_list)
print(grocery_list)
# Out:
# [['honey', 'potatoes', 'Juice'], ['do 255 assignment', '256 assignment'], '272 enterprise software']
# ['honey', 'potatoes', 'Juice']

# %%
grocery_list.insert(1,'onions')
grocery_list
# Out:
# ['honey', 'onions', 'potatoes', 'Juice']

# %%
to_do_list.insert(1,'chai')
to_do_list
# Out:
# [['honey', 'onions', 'potatoes', 'Juice'],
#  'chai',
#  ['do 255 assignment', '256 assignment'],
#  '272 enterprise software']

# %%
to_do_list.remove('chai')
to_do_list
# Out:
# [['honey', 'onions', 'potatoes', 'Juice'],
#  ['do 255 assignment', '256 assignment'],
#  '272 enterprise software']

# %%
grocery_list.sort()
#grocery_list.remove('Juice')
grocery_list
# Out:
# ['honey', 'onions', 'potatoes']

# %%
grocery_list.reverse()
grocery_list
# Out:
# ['potatoes', 'onions', 'honey']

# %%
to_do_list2= grocery_list + other_items
to_do_list2
# Out:
# ['potatoes', 'onions', 'honey', 'do 255 assignment', '256 assignment']

# %%
#Tuple : the are immutable
pi_tuple=(1,2,3,4)
new_list= list(pi_tuple)
new_tuple = tuple(new_list)
len(pi_tuple)
# Out:
# 4

# %%
#Dictionary
#cannot be joined like lists
di={'A':'apple','B':'ball','C':'car','D':'doll',1: 234}
del di['D']
print(di)
# Out:
# {'A': 'apple', 'B': 'ball', 'C': 'car', 1: 234}

# %%
di[1]=567
print(di)
# Out:
# {'A': 'apple', 'B': 'ball', 'C': 'car', 1: 567}

# %%
di['A']
# Out:
# 'apple'

# %%
di.get('A')
# Out:
# 'apple'

# %%
di.keys()
# Out:
# dict_keys(['A', 'B', 'C', 1])

# %%
di.values()
# Out:
# dict_values(['apple', 'ball', 'car', 567])

# %%
#if elif else
age=28
if age > 16 and age <18:
  print('u are between 16 and 18')
elif age>= 18 and age <=20:
  print('18 and 20')
elif age >20:
  print('u are above 20 so u can drive')
# Out:
# u are above 20 so u can drive

# %%
#loop

for x in range(0,10):
  print(x , end="")
# Out:
# 0123456789

# %%
list_ex = [[9,7,3,4],[2,4,5,6],[8,6,3,4]]
for x in range(0,3):
  for y in range(0,4):
    print(list_ex[x][y], end="")
# Out:
# 973424568634

# %%
#while loop is used when u are not sure of how many iterations
import random
ran=random.randrange(0,100)
while(ran!=15):
  print(ran, end="")
  ran=random.randrange(0,100)
# Out:
# 383232729453288196923982486753517521947555963759436634822637387124094665138706347632661937441547465

# %%
#while loop instead of for loop
i=0;
while(i<20):
  if(i%2 ==0):
    print(i)
  elif(i==9) :
    break
  else: 
    i+=1
    continue
    #continue will jump everything inside loop and goes back to while condition check
    print("will i get printed")
  i+=1
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
#functions
import sys
print('whats ur name')
nam = sys.stdin.readline()
print('Hello',nam)
# Out:
# whats ur name
# Hello

# %%
nam=sys.stdin.readline()

# %%
long_string='play with colab and Play with AI pair programmer in visual studio code'
print(long_string[0:5])
print(long_string[:-4])
print(long_string[-19:])
print("%c is %s Letter, number %d is also %s as much as %.5f" % ('C','favourite',3,'favourite',.1))
# Out:
# play
# play with colab and Play with AI pair programmer in visual studio
#  visual studio code
# C is favourite Letter, number 3 is also favourite as much as 0.10000

# %%
print(long_string.capitalize())
print(long_string.find("programmer"))
print(long_string.replace("and Play with ",""))
print(long_string.strip())
# Out:
# Play with colab and play with ai pair programmer in visual studio code
# 38
# play with colab AI pair programmer in visual studio code
# play with colab and Play with AI pair programmer in visual studio code

# %%
#convert string into list
quote_list=long_string.split(" ")
print(quote_list)
# Out:
# ['play', 'with', 'colab', 'and', 'Play', 'with', 'AI', 'pair', 'programmer', 'in', 'visual', 'studio', 'code']

# %%
#Write to a file
test_file=open('file.txt','wb')
print(test_file.mode)
print(test_file.name)
test_file.write(bytes('I want to add these lines \n','UTF-8'))
test_file.close()
# Out:
# wb
# file.txt

# %%
#read to a file
read_file=open('file.txt','r+')
print(read_file.read())
# Out:
# I want to add these lines

# %%
#Class and Objects
class Animal:
  __name = ""
  __height = ''
  __weight = ''
  __sound = ''

  def __init__(self,name,height,weight,sound) -> None:
    self.__name= name
    self.__height=height
    self.__weight=weight
    self.__sound=sound


  def set_name(self,name):
    self.name = name
  
  def get_name(self):
    return self.__name

  def set_height(self,height):
    self.height = height
  
  def get_height(self):
    return self.__height
  
  def set_weight(self,weight):
    self.weight = weight
  
  def get_weight(self):
    return self.__weight
    
  def set_sound(self,sound):
    self.sound = sound
  
  def get_sound(self):
    return self.__sound
  
  def toString(self):
    return "{} is the animal which has height {} and weight {}".format(self.__name,self.__height,self.__weight)
  
cat= Animal("whisker",10,10,"moo")
print(cat.toString())
# Out:
# whisker is the animal which has height 10 and weight 10

# %%
#inheritance

class Dog(Animal):
  __owner = ""

  def __init__(self, name, height, weight, sound,owner):
    self.__owner=owner
    super().__init__(name, height, weight, sound)
  
  def set_owner(self,owner):
    self.__owner=owner

  def get_owner(self):
    return self.__owner
  
  def get_type(self):
    print("dog")

#method overridding

  def toString(self):
    return "{} is the animal which has height {} and weight {}and has owner {}".format(self.__name,self.__height,self.__weight,self.__owner)
    
  def multiple_sounds(self, how_many=None):
    if how_many is None:
      print(self.get_sound())
    else:
      print(self.get_sound()*how_many)

# %%
spot = Dog("spot",53,27,"ruff","Derek")
